# %% [markdown]
# ## 使用 tf.keras 搭建神经网络
#
# 使用 tf.keras 搭建神经网络有着基本固定的套路，并且可以极大的简化搭建神经网络所用的代码量。
#
# 下面来逐步讲解使用 tf.keras 搭建神经网络的六个基本步骤：
#  1. import 相关模块
#  2. 指定输入网络的训练集和测试集
#  3. 使用 tf.keras.models.Sequential 来逐层搭建网络结构模型 model
#  4. 使用 model.compile() 来配置训练方法
#  5. 使用 model.fit() 来执行训练过程
#  6. 使用 model.summary() 来打印网络结构

# %% [markdown]
#  ### 1.  导入相关模块
#
#  比如 `import tensorflow as tf` 等

# %% [markdown]
# ### 2. 指定输入网络的训练集和测试集
#
# 比如指定训练集的输入 x_train 和标签 y_train，测试集的输入 x_test 和标签 y_test。

# %% [markdown]
# ### 3. 逐层搭建网络结构
#
# 这一步涉及到的常用的 tf.keras API 如下所示：
#
# #### 3.1 tf.keras.models.Squential()
#
# Sequential 函数是一个容器，描述了神经网络的网络结构，在 Sequential 函数的输入参数中描述从输入层到输出层的网络结构。
#
# 在构建网络结构的步骤中，自然少不了对各种类型的网络层进行表示，常用的有下面几种类型
#
# ##### 3.1.1 拉直层
#
# `tf.keras.layers.Flatten()`
#
# 拉直层可以变换张量的尺寸，把输入特征拉直为一维数组，是不含计算参数的层。
#
# ##### 3.1.2 全连接层：
#
# `tf.keras.layers.Dense(神经元个数, activation="激活函数", kernel_regularizer="正则化方法")`
#
# 其中：
#  + activation 可选参数有 `"relu"`、`"softmax"`、`"sigmoid"`、`"tanh"` 等
#  + kernel_regularizer 可选参数有 `tf.keras.regularizers.l1()`、`tf.keras.regularizers.l2()`
#
# ##### 3.1.1 卷积层：
#
# `tf.keras.layers.Conv2D(filter, kernel_size, strides, padding)`
#
# 其中：
#  + filter 表示卷积核个数
#  + kernel_size 表示卷积核尺寸
#  + strides 表示卷积步长或者步幅，是应用滤波器的位置间隔
#  + padding 表示填充，即向输入数据的周围填入固定数据，可选参数为 `"valid"` 或者 `"same"`
#
# ##### 3.1.1 LSTM层：
#
# `tf.keras.layers.LSTM()`

# %% [markdown]
# ### 4. 配置训练方法
#
# 这一步涉及到的函数主要是 `model.compile(optimizer, loss, metrics)`。用于配置神经网络的训练方法，告知训练时使用的优化器、损失函数和准确率评测标准
#
# #### 4.1 optimzier
#
# 即优化器，参数值可以使用字符串的形式给出优化器名字，也可以使用函数形式，使用函数形式时，可以同时设置优化器的学习率、动量和超参数等。可用选项简单介绍如下：
#
#  +`"sgd"` 或者 `tf.optimizers.SGD( lr=学习率. decay=学习率衰减率, momentum=动量参数)`
#  + `"adagrad"` 或者 `tf.keras.optimizers.Adagrad(lr=学习率, decay=学习率衰减率)`
#  + `"adadelta"` 或者 `tf.keras.optimizers.Adadelta(lr=学习率, decay=学习率衰减率)`
#  +`"adam"` 或者 `tf.keras.optimizers.Adam (lr=学习率, decay=学习率衰减率)`
#
# #### 4.2 loss
#
# 即损失函数，同样也可以给出字符串形式的损失函数名字，或者函数形式。可用选项简单介绍如下：
#  + `"mse"` 或者 `tf.keras.losses.MeanSquaredError()`
#  + `"sparse_categorical_crossentropy"` 或者 `tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)`
#
# 对参数 `from_logits` 的理解：有些神经网络的输出是经过了 softmax 等函数的概率分布，有些则不经概率分布直接输出，而参数 `from_logits` 就是在询问是否是原始输出，也就是没有经过概率分布的输出，取 False 时表示转化为概率分布，取 True 时表示没有转化为概率分布，直接输出。
#
# #### 4.3 metrics
#
# 即标注网络评测指标。可用选项简单介绍如下：(y_ 为真实值，y 为预测值)
#
#  + `"accuracy"`表示真实值 y_ 和输出预测值 y 都是数值形式，如 `y_=[1]`、`y=[1]`
#  + `"categorical_accuracy"`表示真实值 y_ 和输出预测值 y 都是独热码或概率分布表示，如 `y_=[0, 1, 0]`、`y=[0.256, 0.695, 0.048]`
#  + `"sparse_ categorical_accuracy"`表示真实值 y_  是以数值形式给出，输出预测值 y 是以独热码或概率分布形式给出。如 `y_=[1]`、`y=[0.256, 0.695, 0.048]`

# %% [markdown]
# ### 5. 执行训练过程
#
# 这一步使用的 API 主要为
#
# ```python
# model.fit(训练集的输入特征， 训练集的标签，
#         batch_size=每次喂入神经网络的样本数,
#         epochs=迭代数据集的次数,
#         validation_data=(测试集的输入特征，测试集的标签)，
#         validataion_split=从训练集中划分多少比例的数据作为测试集，
#         validation_freq=多少次epoch测试一次)
# ```
#
# `validation_data` 和 `validataion_split` 这两个参数二者选其一即可。

# %% [markdown]
# ### 6. 打印网络结构
#
# 使用 `model.summary()` 函数来打印网络结构和参数统计

# %% [markdown]
# ### 实践：使用 tf.keras 重新实现神经网络对 iris 数据集的分类

# %% [markdown]
# ### 1. import 相关模块

# %%
import tensorflow as tf
import numpy as np
from sklearn import datasets # 为了使用 iris 数据集

# %% [markdown]
# ### 2. 指定输入网络的训练集和测试集

# %%
# 导入数据集
x_train = datasets.load_iris().data
y_train = datasets.load_iris().target

# 乱序数据集
np.random.seed(666)
np.random.shuffle(x_train)
np.random.seed(666)
np.random.shuffle(y_train)

# %% [markdown]
# ###  3. 使用 tf.keras.models.Sequential 来逐层搭建网络结构模型 model
#
# 使用单层全连接网络结构，第一个参数表示神经元个数，第二个参数表示网络所使用的激活函数，第三个参数表示选用的正则化方法。

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(3, activation="softmax",kernel_regularizer=tf.keras.regularizers.l2())
])

# %% [markdown]
# ###  4. 使用 model.compile() 来配置训练方法

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(lr=0.1),
             loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
             metrics=['sparse_categorical_accuracy'])

# %% [markdown]
# ### 5. 使用 model.fit() 来执行训练过程

# %%
model.fit(x_train, y_train, batch_size=32, epochs=500, validation_freq=20, validation_split=0.2)
# Out:
# Train on 120 samples, validate on 30 samples
# Epoch 1/500
# 120/120 [==============================] - 0s 2ms/sample - loss: 2.6206 - sparse_categorical_accuracy: 0.3500
# Epoch 2/500
# 120/120 [==============================] - 0s 67us/sample - loss: 0.8692 - sparse_categorical_accuracy: 0.6000
# Epoch 3/500
# 120/120 [==============================] - 0s 67us/sample - loss: 0.8284 - sparse_categorical_accuracy: 0.6500
# Epoch 4/500
# 120/120 [==============================] - 0s 58us/sample - loss: 0.7043 - sparse_categorical_accuracy: 0.6583
# Epoch 5/500
# 120/120 [==============================] - 0s 75us/sample - loss: 0.7734 - sparse_categorical_accuracy: 0.6917
# Epoch 6/500
# 120/120 [==============================] - 0s 66us/sample - loss: 0.8047 - sparse_categorical_accuracy: 0.6750
# Epoch 7/500
# 120/120 [==============================] - 0s 83us/sample - loss: 0.6031 - sparse_categorical_accuracy: 0.7500
# Epoch 8/500
# ...

# %% [markdown]
# ### 6. 使用 model.summary() 来打印网络结构

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                multiple                  15
# ...
# Total params: 15
# Trainable params: 15
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 自定义网络结构
#
# 在上述搭建神经网络的过程中，使用的是 `tf.keras.models.Sequential` 来搭建的网络模型，使用该 API 可以很方便的搭建出“上层输出就是下层输入”的顺序网络结构，但是无法写出一些带有跳连的非顺序网络结构。这个时候就需要自定义网络模型，可以实现继承自 Model (tf.keras.Model) 的 class 类来封装一个神经网络结构，基本格式如下：
#
# ```python
# class MyModel(Model):
#     def __init__(self):
#         super(MyModel, self).__init__()
#         # 自定义并初始化网络结构
#
#     def call(self, x):
#         # 调用自定义网络结构，实现前向传播
#         return y
#
# # 使用自定义模型
# model = MyModel()
# ```
#
# 因此，只需要修改“六步法”中的第三步，只需要修改构建神经网络的方式，其他步骤不需要变化。下面来实现一个鸢尾花识别的自定义网络结构

# %%
from tensorflow.keras import Model
from tensorflow.keras.layers import Dense

# %%
class IrisModel(Model):
    def __init__(self):
        super(IrisModel, self).__init__()
        self.d1 = Dense(3, activation="softmax",kernel_regularizer=tf.keras.regularizers.l2())
    
    def call(self, x):
        y = self.d1(x)
        return y

# %%
model = IrisModel()

# %% [markdown]
# 如果单纯的与使用 Sequential 的方式做对比，会发现自定义网络结构会看着稍显复杂。这是因为鸢尾花识别的功能其实没必要使用自定义的网络结构，而至于自定义网络结构的可扩展性会在之后讲到其他类型的神经网络时真正的展现出来。
#
# 其他步骤不变。

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(lr=0.1),
             loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
             metrics=['sparse_categorical_accuracy'])

# %%
model.fit(x_train, y_train, batch_size=32, epochs=500, validation_freq=20, validation_split=0.2)
# Out:
# Train on 120 samples, validate on 30 samples
# Epoch 1/500
# 120/120 [==============================] - 0s 1ms/sample - loss: 2.3028 - sparse_categorical_accuracy: 0.5750
# Epoch 2/500
# 120/120 [==============================] - 0s 75us/sample - loss: 0.6854 - sparse_categorical_accuracy: 0.8083
# Epoch 3/500
# 120/120 [==============================] - 0s 67us/sample - loss: 0.6722 - sparse_categorical_accuracy: 0.7667
# Epoch 4/500
# 120/120 [==============================] - 0s 66us/sample - loss: 0.8870 - sparse_categorical_accuracy: 0.6417
# Epoch 5/500
# 120/120 [==============================] - 0s 67us/sample - loss: 0.7019 - sparse_categorical_accuracy: 0.7000
# Epoch 6/500
# 120/120 [==============================] - 0s 83us/sample - loss: 1.0658 - sparse_categorical_accuracy: 0.5583
# Epoch 7/500
# 120/120 [==============================] - 0s 67us/sample - loss: 0.7159 - sparse_categorical_accuracy: 0.8167
# Epoch 8/500
# ...

# %%
model.summary()
# Out:
# Model: "iris_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              multiple                  15
# ...
# Total params: 15
# Trainable params: 15
# Non-trainable params: 0
# _________________________________________________________________
